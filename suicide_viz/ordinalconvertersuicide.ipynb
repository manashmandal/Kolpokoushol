# %%
import pandas as pd

# %%
df = pd.read_csv('suicide_history.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Age', 'Gender', 'Profession', 'Methodology', 'Reason', 'Time',
#        'District', 'Source'],
#       dtype='object')

# %%
df = df.sort('Age')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
df['Reason'] = [x.lower() for x in df['Reason']]
df = df[(df['Reason'] != 'not given') & (df['Reason'] != '-') & (df['Reason'] != 'not known') & (df['Reason'] != 'unknown')]

# %%
# Category 8-12
df_8_12 = df[(df['Age'] >= 8) & (df['Age'] <= 12)]

# %%
# Category 13-18
df_13_18 = df[(df['Age'] >= 13) & (df['Age'] <= 18)]

# %%
# Category 19-26
df_19_26 = df[(df['Age'] >= 19) & (df['Age'] <= 26)]

# %%
# Category 27-35
df_27_35 = df[(df['Age'] >= 27) & (df['Age'] <= 35)]

# %%
# Category 36-50
df_36_50 = df[(df['Age'] >= 36) & (df['Age'] <= 50)]

# %%
# Category 51-80
df_51_80 = df[(df['Age'] >= 51) & (df['Age'] <= 80)]

# %%
# Category 81-103
df_81_103 = df[(df['Age'] >= 81) & (df['Age'] <= 103)]

# %%
df_81_103
# Out:
#          Date  Age  Gender Profession Methodology       Reason     Time  \
# 432  2/7/2012   85  Female  not given     Hanging  family feud  5:00:00
# 795  9/9/2013  103    Male  not given     Hanging  family feud        -
#
#       District                                             Source
# 432  Shatkhira  http://archive.thedailystar.net/newDesign/news...
# 795  Joypurhat  http://archive.thedailystar.net/beta2/news/sni...

# %%
df.shape
# Out:
# (673, 9)

# %%
df_8_12['Age'] = ['8 to 12' for i in range(df_8_12.shape[0])]
df_13_18['Age'] = ['13 to 18' for i in range(df_13_18.shape[0])]
df_19_26['Age'] = ['19 to 26' for i in range(df_19_26.shape[0])]
df_27_35['Age'] = ['27 to 35' for i in range(df_27_35.shape[0])]
df_36_50['Age'] = ['36 to 50' for i in range(df_36_50.shape[0])]
df_51_80['Age'] = ['51 to 80' for i in range(df_51_80.shape[0])]
df_81_103['Age'] = ['81 to 103' for i in range(df_81_103.shape[0])]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfs = pd.concat(frames)

# %%
frames = [df_8_12, df_13_18, df_19_26, df_27_35, df_36_50, df_51_80, df_81_103]

# %%
dfs
# Out:
#            Date        Age  Gender  \
# 472   3/30/2012    8 to 12    Male
# 627   9/30/2012    8 to 12  Female
# 188    2/8/2011    8 to 12  Female
# 636  10/20/2012    8 to 12  Female
# 230    4/5/2011    8 to 12    Male
# 670  12/24/2012    8 to 12  Female
# 592    9/4/2012    8 to 12    Male
# 179   1/25/2011    8 to 12  Female
# 763   7/24/2013    8 to 12  Female
# 478    4/3/2012    8 to 12    Male
# 388  11/27/2011    8 to 12    Male
# 359   10/3/2011    8 to 12  Female
# 626   9/29/2012    8 to 12  Female
# 962  10/23/2014    8 to 12    Male
# 306   7/19/2011    8 to 12  Female
# 529    6/9/2012    8 to 12  Female
# 14     2/3/2010    8 to 12  Female
# 75    7/19/2010    8 to 12  Female
# 688    2/8/2013    8 to 12  Female
# 897   5/31/2014    8 to 12  Female
# 679   1/10/2013    8 to 12  Female
# 696    3/6/2013    8 to 12  Female
# 327   8/16/2011    8 to 12  Female
# 640  10/22/2012    8 to 12    Male
# 913   6/23/2014    8 to 12    Male
# 590   8/27/2012   13 to 18  Female
# 674  12/28/2012   13 to 18  Female
# 253   4/22/2011   13 to 18  Female
# 242   4/17/2011   13 to 18  Female
# 90    8/11/2010   13 to 18  Female
# ..          ...        ...     ...
# 272    6/4/2011   36 to 50    Male
# 876    4/2/2014   51 to 80    Male
# 316   7/29/2011   51 to 80    Male
# 880   4/16/2014   51 to 80    Male
# 939    9/1/2014   51 to 80    Male
# 496   4/27/2012   51 to 80    Male
# 233   4/10/2011   51 to 80    Male
# 503    5/5/2012   51 to 80    Male
# 485    4/9/2012   51 to 80    Male
# 424    2/2/2012   51 to 80    Male
# 888    5/3/2014   51 to 80    Male
# 308   7/21/2011   51 to 80    Male
# 547   7/12/2012   51 to 80    Male
# 452   3/13/2012   51 to 80    Male
# 817  11/13/2013   51 to 80    Male
# 486   4/10/2012   51 to 80    Male
# 108   8/29/2010   51 to 80  Female
# 815   11/8/2013   51 to 80    Male
# 865   3/16/2014   51 to 80  Female
# 455   3/17/2012   51 to 80    Male
# 303   7/13/2011   51 to 80    Male
# 446    3/3/2012   51 to 80    Male
# 471   3/30/2012   51 to 80    Male
# 252   4/20/2011   51 to 80  Female
# 392   12/3/2011   51 to 80    Male
# 26    2/27/2010   51 to 80    Male
# 9     1/28/2010   51 to 80  Female
# 480    4/7/2012   51 to 80    Male
# 432    2/7/2012  81 to 103  Female
# 795    9/9/2013  81 to 103    Male
#
#                                            Profession  \
# 472                                           Student
# 627                                           Student
# 188                                           student
# 636                                         not given
# 230                                           student
# 670                                           Student
# 592                                           Student
# 179                                           student
# 763                                           Student
# 478                                           Student
# 388                                           student
# 359                                           student
# 626                                         not given
# 962                                         not given
# 306                                           student
# 529                                           Student
# 14                                            Student
# 75                                            Student
# 688                                           Student
# 897                                         not given
# 679                                           student
# 696                                         not given
# 327                                         not given
# 640                                           Student
# 913                                           Student
# 590                                           Student
# 674                                           Student
# 253                                     slum residant
# 242                                           student
# 90                                          not given
# ..                                                ...
# 272         former member of Gopalganj Union Parishad
# 876                                            Farmer
# 316                                         Policeman
# 880                                     Not mentioned
# 939                Owner of Afsar Group of Industries
# 496                                         not given
# 233                                  police constable
# 503                                        Tea vendor
# 485                                         not given
# 424                                      Stock broker
# 888                                        Journalist
# 308                                         not given
# 547  Joint Secretary (public Administration Ministry)
# 452                                  Ex-BCIC official
# 817                                         not given
# 486                                         not given
# 108                                         not given
# 815                                         not given
# 865                                           Elderly
# 455                                   Freedom fighter
# 303                                         not given
# 446                                         not given
# 471                                            Doctor
# 252                                         not given
# 392                                         not given
# 26                                          not given
# 9                                             Student
# 480                                         not given
# 432                                         not given
# 795                                         not given
#
#                   Methodology                         Reason  \
# 472                   Hanging                    family feud
# 627                    Poison                     allegation
# 188                    Poison                    family feud
# 636                   Hanging               physical illness
# 230                    Poison                    family feud
# 670                   Hanging                    family feud
# 592                   Hanging                    family feud
# 179                    Poison                failing in exam
# 763                   Hanging                    family feud
